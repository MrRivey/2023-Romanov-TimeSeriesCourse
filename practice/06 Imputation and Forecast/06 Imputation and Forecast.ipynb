# %% [markdown]
# ## Анализ и прогнозирование временных рядов методами искусственного интеллекта

# %% [markdown]
# ### **Практическая работа 4. Востановление пропусков и прогноз значений временного ряда.**

# %% [markdown]
# ##### *Краткое описание*

# %% [markdown]
# ##### *Структура и оценивание*

# %% [markdown]
# ##### *Сроки выполнения*

# %% [markdown]
# #### **4.1 Аналитечкие методы востановления временного ряда**

# %% [markdown]
# ##### *Краткое описание*

# %% [markdown]
# В данном пункте практической работы вам предстоит познакомиться с базовыми, аналитическими методами восстановления временных рядов.
# Для выполнения данного пункта из каждой группы методов, представленных в ***табл. 5.1*** вам необходимо выбрать по одному методу восстановления ряда. При работе с первой группой, вам необходимо самостоятельно реализовать выбранный метод.
#
# **Табл. 4.1** - Группы аналитических методов восстановления.
# №|Название группы|Модели и методы|
# --|-------------|----|
# 1|Заполнение существующими значениями ряда|Средненим, медианной, Hot-Deck|
# 2|Заполнение на основе близки значений|[Интерполяция](https://scikit-learn.org/stable/auto_examples/linear_model/plot_polynomial_interpolation.html),  [KNNi](https://scikit-learn.org/stable/modules/generated/sklearn.impute.KNNImputer.html)|
# 3|На основе матричных разложений|[CD-Rec](#Fixme:Дат ссылку), [SVD](https://pypi.org/project/fancyimpute/)|

# %% [markdown]
# ##### 4.1.1 Загрузка и подготовка данных
# fixme: добавить описание данных и саму выгрузку данных

# %% [markdown]
# Самостоятельно реализуйте функцию, принимающую на вход многомерный временной ряд и возвращающий:
# 1. Все подпоследовательности временного ряда, в которых некоторые значения временного ряда были заменены nan значениями.
# 2. Индексы пропущенных значени
#
# Процент проущенных значений должен регулироваться отедельным параметром.

# %% [markdown]
# ##### 4.1.2 Заполнение существующими значениями ряда
# fixme: Добавить краткое описание данной группы методов

# %% [markdown]
# Самостоятельно реализуйте один метод из первой группы ***табл. 5.1*** и проведите востановление данных, сохратив результаты востановления.

# %% [markdown]
# ##### 4.1.3 Заполнение на основе близки значений
# fixme: Добавить краткое описание данной группы методов

# %% [markdown]
# Используя документацию одного из методов востановления второй группы ***табл. 5.1*** и проведите востановление данных, сохратив результаты востановления.

# %% [markdown]
# ##### 4.1.4 Заполнение на основе близки значений
# fixme: Добавить краткое описание данной группы методов

# %% [markdown]
# Используя документацию одного из методов востановления третей группы ***табл. 5.1*** и проведите востановление данных, сохратив результаты востановления.

# %% [markdown]
# ##### 4.1.5 Сравнение результатов востановление.

# %% [markdown]
# Используюя следующие библиотеки(список библиотек) отдельно для каждой группы методов постройте методов основные метрики оценки качества востановления.
# На основе метрик постройте отберите лучшие методы востановление метрик и выберите лучшую группу востановления. Для лучших методов из каждой группы постройте графики сравнения реальных и востановленных данных. Обьясните результаты и сделайте вывод.

# %% [markdown]
# *Вывод*:

# %% [markdown]
# #### **4.2 Нейросетевые методы востановления временного ряда**

# %% [markdown]
# ##### *Краткое описание*

# %% [markdown]
# В данном пункте практической работы вам предстоит познакомиться с некоторыми нейросетевыми методами восстановления временных рядов.
# Для выполнения данного пункта вам предстоит самостоятельно реализовать структуру нейросетевой, модели основанной на GRU нейронах и сравнить ее с другими нейросетевыми методами восстановления При сравнение с 3 группой из **табл. 2** вам необходимо выбрать **один** метод востановления.. Основные блоки обработки данных будут реализованы с использование Pytorch. Вам не запрещается использовать для реализации Keras.
#
#
# **Табл4 5.2** - Нейросетевые методы восстановления.
# №|Название группы|Модели и методы|
# --|-------------|----|
# 1|Линейные нейроны|[Pytorch](https://pytorch.org/docs/stable/generated/torch.nn.Linear.html)|
# 2|Реккуретные нейронны|[Pytorch](https://pytorch.org/docs/stable/generated/torch.nn.GRU.html)|
# 3|Сложные структуры|[SAITS, BRITS, M-RNN](https://github.com/WenjieDu/PyPOTS)|

# %% [markdown]
# ##### 4.2.1 Загрузка и подготовка данных

# %% [markdown]
# ##### 4.2.2 Базовая модель востановлениях данных, построенная на нескольких слоях линейных нейроннах

# %% [markdown]
# Fixme: добавить описание
#
# Вам необходимо будет самостоятельно реализовать:
# 1. функцию производящую инициализацию nan значений какими либо другими значениями.
# 2. функцию производяющую замер времени полного обучения и тестирования модели.

# %% [markdown]
# ##### 4.2.3 Реккурентная модель востановлениях данных

# %% [markdown]
# Fixme: добавить описание
#
# Вам необходимо самостотельно, используя пример из п. 5.1.2 реализовать реккурентную модель с архитектурой указанной ниже и произвести замер времени.

# %% [markdown]
# ##### 4.2.4 Сложные модели нейросетевого востановлениях данных

# %% [markdown]
# Fixme: добавить описание
# Вам необходимо выбрать одну модель из 3 группы таблицы 5.2 и используя документацию произвести восстановления того же ряда. Произведите замер времени.

# %% [markdown]
# ##### 4.2.5 Сравнения результатов.
# Также, как и в пункте 5.1.5 постройте графики сравнения моделей. Дополнительно постройте графики сравнения времени. Сделайте выводы

# %% [markdown]
# #### **4.3 Прогноз временного ряда**

# %% [markdown]
# ##### *Краткое описание*

# %% [markdown]
# Используя модель и [ARIMA](реализация) произвидите прогноз ряда на следующие колличество точек: 1, 5, 10.
# Сравните результаты. Постройте графики прогноза и точности прогноза.
